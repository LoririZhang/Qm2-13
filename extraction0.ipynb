# %% [markdown]
# <a href="https://colab.research.google.com/github/LoririZhang/Qm2-13/blob/main/extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir data

# %%
from pandas.core.indexes.interval import IntervalIndex

import pandas as pd

import pandas

import seaborn as sns

# %matplotlib inline

import pylab

import numpy as np

import matplotlib
# %matplotlib inline

import random

import matplotlib.pyplot as plt
# make the plots a little wider by default
# %matplotlib inline
plt.style.use('ggplot')

pylab.rcParams['figure.figsize'] = (10., 8.)

# %%
data = pandas.read_csv('google_data.csv')
data.head()
# Out:
#                  Region  climate change: (2021)
# 0  District of Columbia                     100
# 1               Vermont                      68
# 2                Alaska                      41
# 3                Oregon                      41
# 4         New Hampshire                      41

# %%
#creating a dataframe for google trends
google_data = "google_data.csv"

google =  pandas.read_csv(google_data, index_col=0)
google.head()
# Out:
#                       climate change: (2021)
# Region
# District of Columbia                     100
# Vermont                                   68
# Alaska                                    41
# Oregon                                    41
# New Hampshire                             41

# %%
google.tail() #just to see the end of the data
# Out:
#              climate change: (2021)
# Region
# Alabama                          20
# Ohio                             20
# Arkansas                         20
# Tennessee                        19
# Mississippi                      17

# %% [markdown]
# # 新段落

# %%
google.describe()
# Out:
#        climate change: (2021)
# count               51.000000
# mean                30.470588
# std                 13.071118
# min                 17.000000
# 25%                 23.000000
# 50%                 27.000000
# 75%                 34.500000
# max                100.000000

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, District of Columbia to Mississippi
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   climate change: (2021)  51 non-null     int64
# dtypes: int64(1)
# memory usage: 816.0+ bytes

# %%
sns.pairplot(google)

# %%
opinion = pandas.read_csv('opinion_data.csv')
opinion.head()
# Out:
#     GeoType         Unnamed: 1   GeoName   TotalPop  happening  \
# 0  National  Number of states         US  251268391     71.827
# 1     State                  1   Alabama    3779877     63.291
# 2     State                  2    Alaska     552673     70.188
# 3     State                  3   Arizona    5414955     72.246
# 4     State                  4  Arkansas    2295104     66.366
#
#    happeningOppose   human  humanOppose  consensus  consensusOppose  ...  \
# 0           14.459  56.540       30.367     57.303           23.389  ...
# 1           17.818  49.350       36.640     47.468           26.865  ...
# 2           17.444  53.277       33.621     56.628           26.673  ...
# 3           15.191  56.428       30.939     57.135           24.560  ...
# 4           18.109  51.238       35.455     48.541           27.555  ...
#
#    localofficials  localofficialsOppose  citizens  citizensOppose  discuss  \
# ...

# %%
#creating a dataframe for opinion
opinion_data = "opinion_data.csv"

opinion =  pandas.read_csv(opinion_data, index_col=0)
opinion.head()
# Out:
#                  Unnamed: 1   GeoName   TotalPop  happening  happeningOppose  \
# GeoType
# National  Number of states         US  251268391     71.827           14.459
# State                     1   Alabama    3779877     63.291           17.818
# State                     2    Alaska     552673     70.188           17.444
# State                     3   Arizona    5414955     72.246           15.191
# State                     4  Arkansas    2295104     66.366           18.109
#
#            human  humanOppose  consensus  consensusOppose  affectweather  ...  \
# GeoType                                                                   ...
# National  56.540       30.367     57.303           23.389         64.469  ...
# State     49.350       36.640     47.468           26.865         53.640  ...
# State     53.277       33.621     56.628           26.673         62.254  ...
# State     56.428       30.939     57.135           24.560         64.224  ...
# ...

# %%
opinion.tail() #just to see the end of the data
# Out:
#         Unnamed: 1        GeoName  TotalPop  happening  happeningOppose  \
# GeoType
# State           47       Virginia   6588765     74.246           12.450
# State           48     Washington   5760561     75.379           13.464
# State           49  West Virginia   1447865     56.918           26.761
# State           50      Wisconsin   4509814     69.452           16.700
# State           51        Wyoming    444650     58.285           25.876
#
#           human  humanOppose  consensus  consensusOppose  affectweather  ...  \
# GeoType                                                                  ...
# State    59.283       28.400     61.107           22.291         67.307  ...
# State    60.097       27.528     63.940           22.698         69.414  ...
# State    42.603       41.302     42.746           33.935         49.264  ...
# State    55.104       32.118     56.383           25.729         63.334  ...
# ...

# %%
opinion.describe()
# Out:
#            TotalPop  happening  happeningOppose      human  humanOppose  \
# count  5.200000e+01  52.000000        52.000000  52.000000    52.000000
# mean   9.664169e+06  70.138231        16.197654  54.758865    32.058404
# std    3.460901e+07   5.149765         3.953981   5.070270     4.035365
# min    4.446500e+05  56.918000         7.351000  42.603000    24.180000
# 25%    1.399498e+06  67.371750        14.189750  51.439500    29.662250
# 50%    3.500379e+06  70.766000        15.323000  55.557000    31.517500
# 75%    5.967612e+06  72.592750        18.495500  57.408000    34.767500
# max    2.512684e+08  83.326000        26.761000  64.687000    41.558000
#
#        consensus  consensusOppose  affectweather  affectweatherOppose  \
# count  52.000000        52.000000      52.000000            52.000000
# mean   55.937635        24.955731      62.863981             7.772481
# std     6.377656         3.652221       6.468951             1.390443
# ...

# %%
opinion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, State to State
# Data columns (total 63 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 1            51 non-null     int64
#  1   GeoName               51 non-null     object
#  2   TotalPop              51 non-null     int64
#  3   happening             51 non-null     float64
#  4   happeningOppose       51 non-null     float64
#  5   human                 51 non-null     float64
#  6   humanOppose           51 non-null     float64
#  7   consensus             51 non-null     float64
#  8   consensusOppose       51 non-null     float64
#  9   affectweather         51 non-null     float64
#  10  affectweatherOppose   51 non-null     float64
#  11  worried               51 non-null     float64
#  12  worriedOppose         51 non-null     float64
#  13  harmplants            51 non-null     float64
# ...

# %%
#happening, worried, futuregen, harmUS, personal

opinion1 = pd.DataFrame(np.random.randn(1,5))

opinion1 = pd.DataFrame()

opinion1.columns = ['happening','worried','futuregen','harmUS','personal']

opinion1.index = ['Alabama', 'Alaska', 'Arizona','Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

opinion1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-66c7ad544536> in <module>
#       5 opinion1 = pd.DataFrame()
#       6
# ----> 7 opinion1.columns = ['happening','worried','futuregen','harmUS','personal']
#       8
#       9 opinion1.index = ['Alabama', 'Alaska', 'Arizona','Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina'...
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
# ...

# %%
opinion1.index = ['Alabama', 'Alaska', 'Arizona']

#'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f5caa428b2cf> in <module>
# ----> 1 opinion1.index = ['Alabama', 'Alaska', 'Arizona']
#       2
#       3 #'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
#       4
#
# ...

# %%
opmean = pandas.read_csv('opinion_mean.csv')

opmean.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-ede05cabbe21> in <module>
# ----> 1 opmean = pandas.read_csv('opinion_mean.csv')
#       2
#       3 opmean.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
opgoogle = pandas.read_csv('opinion_google_reg1.csv')

opgoogle.head()
# Out:
#    Opinion  Google Trends
# 0  56.1396             20
# 1  61.7846             41
# 2  64.0418             28
# 3  58.3030             20
# 4  70.3862             34

# %%
#assigning values in X & y
X = opgoogle['Opinion']
y = opgoogle.iloc[:, -1].values

# %%
print(X[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83b5ba8a36a7> in <module>
# ----> 1 print(X[0])
#
# NameError: name 'X' is not defined

# %%
print(y)
# Out:
# [ 20  41  28  20  34  34  36  30 100  26  20  37  29  24  26  30  25  26
#   23  35  37  35  23  29  17  21  39  28  23  41  25  32  31  23  24  20
#   23  41  25  36  21  26  19  22  31  68  32  39  26  26  27]

# %%
#splitting testdata into x_train, x_test, y_train, y_test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=50, random_state=42)

# %%
print(X_train)
# Out:
# [[62.3028]]

# %%
print(X_test)
# Out:
# [[64.1594]
#  [60.7268]
#  [65.77  ]
#  [58.3454]
#  [59.0794]
#  [65.0586]
#  [54.735 ]
#  [70.4312]
#  [58.303 ]
#  [69.3458]
#  [66.2286]
#  [74.929 ]
#  [61.0978]
#  [67.4534]
#  [67.3862]
#  [70.3862]
#  [56.1296]
#  [62.4974]
#  [60.8172]
#  [49.5018]
#  [60.0186]
#  [63.9992]
#  [58.8366]
#  [58.0334]
#  [58.5234]
#  [59.1876]
#  [63.7834]
#  [56.1396]
#  [65.9048]
#  [57.9616]
#  [51.5822]
#  [64.4528]
#  [62.8586]
#  [65.2398]
#  [61.7846]
#  [69.1088]
#  [64.0418]
#  [64.884 ]
#  [59.543 ]
#  [63.0356]
#  [58.7716]
#  [62.0404]
#  [61.9996]
#  [57.3792]
#  [50.3726]
#  [70.1378]
#  [64.3556]
#  [57.9074]
#  [56.6958]
#  [64.2574]]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

LinearRegression()
# Out:
# LinearRegression()

# %%
#Predicting Y from linear regression model
y_pred = lr.predict(X_test)

# %%
#Ploting Graph

plt.scatter(X_train, y_train, color='red', marker='x')
plt.plot(X_train, lr.predict(X_train), color='blue')
plt.title('Linear Regression for Opinions and Google Trends')
plt.xlabel('Opinions on Climate Change')
plt.ylabel('Google searches for climate change')
plt.show()
